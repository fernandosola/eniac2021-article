# %% [markdown]
# # Experimentos para os dados estruturados

# %%
import datetime
import re
import json
import yaml
import sys
import os
import logging
import logging.config
import time
import multiprocessing
from collections import OrderedDict
import requests
import sqlalchemy
import string
import unicodedata
import yaml
import warnings
warnings.filterwarnings('ignore')

from lightgbm import LGBMClassifier
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib.cm import ScalarMappable
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

import tqdm

import numpy as np
from scipy.sparse import issparse

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    make_scorer,
    accuracy_score,
    balanced_accuracy_score,
    average_precision_score,
    brier_score_loss,
    f1_score,
    log_loss,
    precision_score,
    recall_score,
    jaccard_score,
    roc_auc_score,
    classification_report,
    confusion_matrix,
    roc_curve,
    precision_recall_curve,
    auc,
)
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.neural_network import MLPClassifier

from sklearn.feature_selection import SelectPercentile, VarianceThreshold, SelectFromModel
from sklearn.model_selection import GridSearchCV, cross_val_score, cross_validate, RepeatedStratifiedKFold
from sklearn.calibration import CalibratedClassifierCV

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler, Binarizer
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD, PCA

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, FeatureUnion

from lightgbm import LGBMClassifier

import xgboost as xgb
from xgboost import XGBClassifier

import joblib
from joblib import delayed, Parallel

#################################
# VARIÁVEIS GLOBAIS
#################################
N_JOBS = 100
BASE_DIR = './'
DEFAULT_RANDOM_STATE = 42

#################################
# LOGS
#################################
with open(os.path.join(BASE_DIR, 'log.conf.yaml'), 'r') as f:
    config = yaml.safe_load(f.read())
    logging.config.dictConfig(config)
    
#################################
# CONFIGURAÇÕES
#################################
pd.options.display.max_rows = 500

# %%
# # manter no dataset apenas manifestacoes até maio
# sdp = sqlalchemy.create_engine('mssql+pyodbc://SDP_DIE_BD')
# query = """
# SELECT [IdManifestacao]
# FROM [db_denuncias_origem].[eouv].[Manifestacao]
# WHERE [DatRegistro] < convert(datetime, '01/06/2021', 103)
# ORDER BY [DatRegistro] desc
# """
# df_datas = pd.read_sql(query, sdp)

# %%
# # Leitura dos dados estruturados extraídos das denúncias. 
# # Informações completamente anonimizadas.
# df = pd.read_parquet('datasets/df_treinamento_faro.parquet')
# df = df[df['IdManifestacao'].isin(df_datas['IdManifestacao'])].copy()
# df_anonimizado = df.copy()
# df_anonimizado['LABEL'] = df_anonimizado['GrauAptidao'].apply(lambda x: 1 if x > 50 else 0)
# df_anonimizado.drop(columns=['IdManifestacao','GrauAptidao','TxtFatoManifestacao','TextoAnexo'], inplace=True)
# df_anonimizado.columns = [f'F{i:>03}' for i, c in enumerate(df_anonimizado.columns[:-1])] + ['LABEL']
# df = df_anonimizado

# %%
# # Divisão dos dados em treino e teste
# X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['LABEL']), df['LABEL'], test_size=.2, random_state=DEFAULT_RANDOM_STATE, stratify=df['LABEL'])

# # altera a escala das features para um intervalo entre 0 e 1.

# X_train_original = X_train.copy()
# X_test_original = X_test.copy()

# scaler = MinMaxScaler()
# scaler.fit(X_train)
# X_train = scaler.transform(X_train)
# X_test = scaler.transform(X_test)

# NUMERO_FEATURES = X_train.shape[1]

# %%
# df_tmp = pd.DataFrame(X_train, columns=X_train_original.columns, index=X_train_original.index)
# df_tmp['LABEL'] = y_train
# df_tmp.to_parquet('datasets/df_train_de.parquet')

# df_tmp = pd.DataFrame(X_test, columns=X_test_original.columns, index=X_test_original.index)
# df_tmp['LABEL'] = y_test
# df_tmp.to_parquet('datasets/df_test_de.parquet')

# %%
df_train = pd.read_parquet('datasets/df_train_de.parquet')
X_train, y_train = df_train.drop(columns=['LABEL']), df_train['LABEL']

df_test = pd.read_parquet('datasets/df_test_de.parquet')
X_test, y_test = df_test.drop(columns=['LABEL']), df_test['LABEL']

NUMERO_FEATURES = X_train.shape[1]

# %% [markdown]
# # Escolha de features

# %%
# métricas utilizadas para avaliação
metrics = ['average_precision','balanced_accuracy','roc_auc']

k_vs_avg_prec_score = []
k_vs_bal_acc_score = []
k_vs_roc_auc_score = []

# cálculo do peso para a classe positiva (utilizado em algoritmos que podem lidar com o dataset desbalanceado)
POS_WEIGHT = y_train.value_counts()[0]/y_train.value_counts()[1]
class_weight = {0: 1, 1: POS_WEIGHT}

for k in tqdm.tqdm_notebook(range(2, NUMERO_FEATURES + 1, 2)):
    
    # seleciona k features utilizando SelectFromModel(RandomForestClassifier)
    selector = SelectFromModel(
        RandomForestClassifier(
            n_estimators=500, 
            class_weight=class_weight, 
            random_state=DEFAULT_RANDOM_STATE, 
            n_jobs=N_JOBS), 
        max_features=k, 
        threshold=-np.inf)
    selector.fit(X_train, y_train)
    
    # transforma o dataset para preservar apenas as features selecionadas
    X_train_fs = selector.transform(X_train)
    
    # realiza validação cruzada com 10 folds estratificados
    rskfcv = RepeatedStratifiedKFold(
        n_splits=10, 
        n_repeats=1, 
        random_state=DEFAULT_RANDOM_STATE)
    
    valores = cross_validate(
        RandomForestClassifier(
            n_estimators=500, 
            class_weight=class_weight, 
            random_state=DEFAULT_RANDOM_STATE, 
            n_jobs=N_JOBS), 
        X_train_fs, 
        y_train, 
        scoring=metrics, 
        cv=rskfcv, 
        n_jobs=N_JOBS
    )
    cv_scores = {k[5:]: np.mean(v) for k, v in valores.items() if k not in ['fit_time', 'score_time']}
    avg_prec, bal_acc, roc_auc = cv_scores['average_precision'],cv_scores['balanced_accuracy'],cv_scores['roc_auc']
    
    logging.info("k = {} - average_precision = {} - balanced_accuracy = {} - roc_auc_score = {}".format(k, avg_prec, bal_acc, roc_auc))
    
    k_vs_avg_prec_score.append(avg_prec)
    k_vs_bal_acc_score.append(bal_acc)
    k_vs_roc_auc_score.append(roc_auc)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=63.0), HTML(value='')))
# [2021-10-11 14:03:50,611][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 2 - average_precision = 0.36249257248836436 - balanced_accuracy = 0.5537127524633829 - roc_auc_score = 0.5434770301089318
# [2021-10-11 14:03:56,199][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 4 - average_precision = 0.45642008264144424 - balanced_accuracy = 0.6052382442037698 - roc_auc_score = 0.6800736789129018
# [2021-10-11 14:04:01,647][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 6 - average_precision = 0.48970079094754143 - balanced_accuracy = 0.6212838003044421 - roc_auc_score = 0.712935199264046
# [2021-10-11 14:04:07,248][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 8 - average_precision = 0.4921078820193383 - balanced_accuracy = 0.6107609217876429 - roc_auc_score = 0.7163226273348722
# [2021-10-11 14:04:12,730][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 10 - average_precision = 0.4938304687918653 - balanced_accuracy = 0.6132872549564452 - roc_auc_score = 0.7194022142941277
# [2021-10-11 14:04:18,301][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 12 - average_precision = 0.49678663872653744 - balanced_accuracy = 0.6187183499517561 - roc_auc_score = 0.7217792114935493
# [2021-10-11 14:04:23,904][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 14 - average_precision = 0.49460613429531736 - balanced_accuracy = 0.6187491995051323 - roc_auc_score = 0.720742453304549
# [2021-10-11 14:04:29,509][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 16 - average_precision = 0.49463382061590916 - balanced_accuracy = 0.6163559252655003 - roc_auc_score = 0.72190817063576
# [2021-10-11 14:04:35,040][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 18 - average_precision = 0.4943102412270708 - balanced_accuracy = 0.6182586766672004 - roc_auc_score = 0.7212954737729497
# [2021-10-11 14:04:40,469][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 20 - average_precision = 0.4962162025311649 - balanced_accuracy = 0.6149300857991065 - roc_auc_score = 0.7213890100835628
# [2021-10-11 14:04:45,237][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 22 - average_precision = 0.4963732202700357 - balanced_accuracy = 0.6168489454482293 - roc_auc_score = 0.7219956964914538
# [2021-10-11 14:04:49,734][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 24 - average_precision = 0.4948906979695319 - balanced_accuracy = 0.6186018262836004 - roc_auc_score = 0.7215703168801054
# [2021-10-11 14:04:54,201][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 26 - average_precision = 0.49373999151658926 - balanced_accuracy = 0.6218335771917076 - roc_auc_score = 0.7207893930537528
# [2021-10-11 14:04:58,801][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 28 - average_precision = 0.4932174754174343 - balanced_accuracy = 0.6170619082064692 - roc_auc_score = 0.7207262057278615
# [2021-10-11 14:05:03,532][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 30 - average_precision = 0.4965537100857656 - balanced_accuracy = 0.6198652623969889 - roc_auc_score = 0.7223475417894009
# [2021-10-11 14:05:08,178][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 32 - average_precision = 0.49432211556002337 - balanced_accuracy = 0.6226486440538196 - roc_auc_score = 0.7216701490475795
# [2021-10-11 14:05:12,648][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 34 - average_precision = 0.4944995152813917 - balanced_accuracy = 0.6207664303874725 - roc_auc_score = 0.7220607457252495
# [2021-10-11 14:05:17,439][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 36 - average_precision = 0.49721092833265884 - balanced_accuracy = 0.6221561890727545 - roc_auc_score = 0.7232036455291536
# [2021-10-11 14:05:22,236][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 38 - average_precision = 0.4969607188052927 - balanced_accuracy = 0.6223818228057427 - roc_auc_score = 0.7220596845197024
# [2021-10-11 14:05:26,773][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 40 - average_precision = 0.4993830897266377 - balanced_accuracy = 0.6221678939759362 - roc_auc_score = 0.7241240374308578
# [2021-10-11 14:05:31,791][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 42 - average_precision = 0.499391098020965 - balanced_accuracy = 0.6219652691794089 - roc_auc_score = 0.7247987528306561
# [2021-10-11 14:05:36,442][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 44 - average_precision = 0.499399244597796 - balanced_accuracy = 0.6211271933808362 - roc_auc_score = 0.7242386913065045
# [2021-10-11 14:05:41,272][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 46 - average_precision = 0.49765597732074207 - balanced_accuracy = 0.622902656139076 - roc_auc_score = 0.7242726304837342
# [2021-10-11 14:05:46,113][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 48 - average_precision = 0.49743379607969007 - balanced_accuracy = 0.6247906662348228 - roc_auc_score = 0.7240150689776758
# [2021-10-11 14:05:50,794][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 50 - average_precision = 0.49959645791833013 - balanced_accuracy = 0.625195514957975 - roc_auc_score = 0.7249256291922856
# [2021-10-11 14:05:55,779][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 52 - average_precision = 0.49749048527071765 - balanced_accuracy = 0.6236648305829176 - roc_auc_score = 0.7240151765610323
# [2021-10-11 14:06:00,763][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 54 - average_precision = 0.496165131206158 - balanced_accuracy = 0.6231997878825544 - roc_auc_score = 0.722993335214185
# [2021-10-11 14:06:05,572][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 56 - average_precision = 0.49911415566758655 - balanced_accuracy = 0.6289910806695652 - roc_auc_score = 0.7252251925063588
# [2021-10-11 14:06:09,987][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 58 - average_precision = 0.4995230412694876 - balanced_accuracy = 0.6194178592172788 - roc_auc_score = 0.7243406707838246
# [2021-10-11 14:06:14,848][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 60 - average_precision = 0.5009682631743265 - balanced_accuracy = 0.624653604831314 - roc_auc_score = 0.7254076692329975
# [2021-10-11 14:06:19,628][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 62 - average_precision = 0.5012596558765995 - balanced_accuracy = 0.6282691276692458 - roc_auc_score = 0.7251454031078024
# [2021-10-11 14:06:24,527][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 64 - average_precision = 0.49967758310481036 - balanced_accuracy = 0.6231547360811994 - roc_auc_score = 0.72452438425221
# [2021-10-11 14:06:29,383][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 66 - average_precision = 0.5001701700099542 - balanced_accuracy = 0.6217954260793908 - roc_auc_score = 0.7243975067493875
# [2021-10-11 14:06:34,057][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 68 - average_precision = 0.5007507122902896 - balanced_accuracy = 0.6269738759309145 - roc_auc_score = 0.7251235120215489
# [2021-10-11 14:06:39,117][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 70 - average_precision = 0.4996907176398479 - balanced_accuracy = 0.6291154710983259 - roc_auc_score = 0.7252581259815087
# [2021-10-11 14:06:43,714][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 72 - average_precision = 0.5011849718757304 - balanced_accuracy = 0.6262371816246416 - roc_auc_score = 0.7256616813182541
# [2021-10-11 14:06:48,618][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 74 - average_precision = 0.49892337291142475 - balanced_accuracy = 0.6255591761660384 - roc_auc_score = 0.7244930975182517
# [2021-10-11 14:06:53,499][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 76 - average_precision = 0.4988648745676666 - balanced_accuracy = 0.6268465872874543 - roc_auc_score = 0.7253102845090723
# [2021-10-11 14:06:58,391][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 78 - average_precision = 0.4989506082892913 - balanced_accuracy = 0.627366454549221 - roc_auc_score = 0.7259552353186003
# [2021-10-11 14:07:03,052][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 80 - average_precision = 0.5003130020365845 - balanced_accuracy = 0.6267854272386767 - roc_auc_score = 0.7248442089254921
# [2021-10-11 14:07:07,856][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 82 - average_precision = 0.49924327724312045 - balanced_accuracy = 0.6277203429972361 - roc_auc_score = 0.7243125925652592
# [2021-10-11 14:07:12,398][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 84 - average_precision = 0.4988874058169784 - balanced_accuracy = 0.6236868734478118 - roc_auc_score = 0.7250097562646255
# [2021-10-11 14:07:17,243][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 86 - average_precision = 0.5007994159963042 - balanced_accuracy = 0.6240211902320404 - roc_auc_score = 0.7262319414748534
# [2021-10-11 14:07:22,234][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 88 - average_precision = 0.5011587440998799 - balanced_accuracy = 0.6250036289930627 - roc_auc_score = 0.7248127171918112
# [2021-10-11 14:07:26,726][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 90 - average_precision = 0.5019063050271623 - balanced_accuracy = 0.6306314141674295 - roc_auc_score = 0.7259206166129385
# [2021-10-11 14:07:31,623][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 92 - average_precision = 0.5017024136925314 - balanced_accuracy = 0.6240486025127423 - roc_auc_score = 0.725127019529452
# [2021-10-11 14:07:36,410][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 94 - average_precision = 0.5023296663344723 - balanced_accuracy = 0.6305516485264322 - roc_auc_score = 0.7259434465896212
# [2021-10-11 14:07:41,318][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 96 - average_precision = 0.5011124691552158 - balanced_accuracy = 0.6262107354155064 - roc_auc_score = 0.7245499334838148
# [2021-10-11 14:07:46,326][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 98 - average_precision = 0.49907392142446005 - balanced_accuracy = 0.6253628868568851 - roc_auc_score = 0.7247697640439915
# [2021-10-11 14:07:51,220][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 100 - average_precision = 0.5001182444068404 - balanced_accuracy = 0.6221370444225601 - roc_auc_score = 0.7241288519157366
# [2021-10-11 14:07:56,096][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 102 - average_precision = 0.4986837805505802 - balanced_accuracy = 0.6254284502499037 - roc_auc_score = 0.7239630588051746
# [2021-10-11 14:08:01,087][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 104 - average_precision = 0.5012855174395998 - balanced_accuracy = 0.630276559647848 - roc_auc_score = 0.7254683003907909
# [2021-10-11 14:08:05,870][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 106 - average_precision = 0.5010515047860715 - balanced_accuracy = 0.6292094128436128 - roc_auc_score = 0.7259809068653229
# [2021-10-11 14:08:10,724][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 108 - average_precision = 0.5036808234050547 - balanced_accuracy = 0.6305428418379501 - roc_auc_score = 0.726132843198086
# [2021-10-11 14:08:15,501][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 110 - average_precision = 0.5005996373246323 - balanced_accuracy = 0.6254519982443392 - roc_auc_score = 0.7260936433295979
# [2021-10-11 14:08:20,302][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 112 - average_precision = 0.500292221608859 - balanced_accuracy = 0.6194937605720099 - roc_auc_score = 0.7250727397319872
# [2021-10-11 14:08:24,967][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 114 - average_precision = 0.5018974904907376 - balanced_accuracy = 0.6328968607056267 - roc_auc_score = 0.7261033923320875
# [2021-10-11 14:08:29,804][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 116 - average_precision = 0.5009942591266585 - balanced_accuracy = 0.626132901917642 - roc_auc_score = 0.7252024180331433
# [2021-10-11 14:08:34,642][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 118 - average_precision = 0.49967479340432125 - balanced_accuracy = 0.6298883843737825 - roc_auc_score = 0.7252716543032744
# [2021-10-11 14:08:39,383][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 120 - average_precision = 0.49813470021525363 - balanced_accuracy = 0.6263002738165524 - roc_auc_score = 0.7238188045672743
# [2021-10-11 14:08:44,297][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 122 - average_precision = 0.5018017494010237 - balanced_accuracy = 0.6265964394884641 - roc_auc_score = 0.7253461558294351
# [2021-10-11 14:08:49,061][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 124 - average_precision = 0.5000692919381832 - balanced_accuracy = 0.6242380172765467 - roc_auc_score = 0.7252529717324139
# [2021-10-11 14:08:53,932][<ipython-input-6-4596cf2e6dfa>:<module>:49 INFO] k = 126 - average_precision = 0.5000773019667907 - balanced_accuracy = 0.6267961660702918 - roc_auc_score = 0.7247299231363915

# %%
# resumo das métricas
df_feature_selection = pd.DataFrame({
    'Número de Features': range(2, NUMERO_FEATURES + 1, 2),
    'Average Precision': k_vs_avg_prec_score,
    'Balanced Accuracy': k_vs_bal_acc_score,
    'ROC AUC': k_vs_roc_auc_score,
})

df_feature_selection[df_feature_selection['Número de Features']%10==0].reset_index(drop=True)
# Out:
#     Número de Features  Average Precision  Balanced Accuracy   ROC AUC
# 0                   10           0.493830           0.613287  0.719402
# 1                   20           0.496216           0.614930  0.721389
# 2                   30           0.496554           0.619865  0.722348
# 3                   40           0.499383           0.622168  0.724124
# 4                   50           0.499596           0.625196  0.724926
# 5                   60           0.500968           0.624654  0.725408
# 6                   70           0.499691           0.629115  0.725258
# 7                   80           0.500313           0.626785  0.724844
# 8                   90           0.501906           0.630631  0.725921
# 9                  100           0.500118           0.622137  0.724129
# 10                 110           0.500600           0.625452  0.726094
# 11                 120           0.498135           0.626300  0.723819

# %%
# gráfico com as métricas

tamanho_vetores = range(2, NUMERO_FEATURES + 1, 2)

import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.size': 13})
fig, ax = plt.subplots(1,2, figsize=(16, 5), dpi=80)
t = list(range(0, NUMERO_FEATURES + 1, 10))

pd.Series(k_vs_avg_prec_score[0:],index=tamanho_vetores).plot(color='#45B39D', ax=ax[0])
ax[0].set_xlabel('Quantidade de features')
ax[0].set_ylabel('Average Precision')
ax[0].grid(which='major',linestyle='--', linewidth=0.5)
ax[0].set_xticks(t)

pd.Series(k_vs_roc_auc_score[0:],index=tamanho_vetores).plot(color='#45B39D', ax=ax[1])
ax[1].set_xlabel('Quantidade de features')
ax[1].set_ylabel('ROC AUC')
ax[1].grid(which='major',linestyle='--', linewidth=0.5)
ax[1].set_xticks(t)
plt.tight_layout()
plt.savefig('./fig_selecao_features.png')
plt.show()

# %%
# gráfico com as métricas

tamanho_vetores = range(2, NUMERO_FEATURES + 1, 2)

import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'font.size': 13})
fig, ax = plt.subplots(1,3, figsize=(16, 5), dpi=80)
t = list(range(0, NUMERO_FEATURES + 1, 10))

pd.Series(k_vs_avg_prec_score[0:],index=tamanho_vetores).plot(color='#45B39D', ax=ax[0])
ax[0].set_xlabel('Quantidade de features')
ax[0].set_ylabel('Average Precision')
ax[0].grid(which='major',linestyle='--', linewidth=0.5)
ax[0].set_xticks(t)

pd.Series(k_vs_bal_acc_score[0:],index=tamanho_vetores).plot(color='#45B39D', ax=ax[1])
ax[1].set_xlabel('Quantidade de features')
ax[1].set_ylabel('Balanced Accuracy Score')
ax[1].grid(which='major',linestyle='--', linewidth=0.5)
ax[1].set_xticks(t)

pd.Series(k_vs_roc_auc_score[0:],index=tamanho_vetores).plot(color='#45B39D', ax=ax[2])
ax[2].set_xlabel('Quantidade de features')
ax[2].set_ylabel('ROC AUC')
ax[2].grid(which='major',linestyle='--', linewidth=0.5)
ax[2].set_xticks(t)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Escolha de um modelo

# %%
# seleciona k features utilizando SelectFromModel(RandomForestClassifier)

k = 20

selector_model=RandomForestClassifier(
    n_estimators=1000, 
    class_weight=class_weight, 
    random_state=DEFAULT_RANDOM_STATE, 
    n_jobs=N_JOBS)

selector = SelectFromModel(selector_model, max_features=k, threshold=-np.inf)
selector.fit(X_train, y_train)

X_train = selector.transform(X_train)
X_test = selector.transform(X_test)

# %%
X_train.shape
# Out:
# (3240, 20)

# %%
# realiza testes com validação cruzada para a escolha do modelo

metrics = ['roc_auc','balanced_accuracy', 'average_precision', 'recall', 'accuracy', 'f1_macro','f1_weighted']

results = [
    
]

model = [
    RandomForestClassifier,
    LogisticRegression,
    XGBClassifier,
    KNeighborsClassifier,
    BaggingClassifier,
    ExtraTreesClassifier,
    SGDClassifier,
    SVC, 
    NuSVC, 
    LinearSVC,
    BernoulliNB, 
    LGBMClassifier,
    MLPClassifier,
    AdaBoostClassifier,
]


params = [
    {
        'n_estimators': [1000],
        'max_depth': [5,7,9],
        'min_samples_split': [2,3],
        'min_samples_leaf': [1,2],
        'class_weight': [class_weight],
        'random_state': [DEFAULT_RANDOM_STATE],
        'max_samples': [.8, 1],
    },
    {
        'penalty' : ['l2'],
        'C' : [1],
        'solver' : ['liblinear'],
        'random_state': [DEFAULT_RANDOM_STATE],
        'class_weight': [class_weight],
    },
    {
        'learning_rate': [0.01],
        'n_estimators': [1000],
        'subsample' : [.8,.45],
        'min_child_weight': [1],
        'max_depth': [3,4,7],
        'random_state': [DEFAULT_RANDOM_STATE],
        'reg_lambda': [2],
        'scale_pos_weight': [POS_WEIGHT]
    },
    {
        'n_neighbors' : [5,7,9,11],
    },
    {
        'n_estimators': [1000],
        'max_samples': [.8],
        'random_state': [DEFAULT_RANDOM_STATE],
    },
    {
        'n_estimators': [1000],
        'max_samples' : [.8],
        'max_depth': [6,7],
        'random_state': [DEFAULT_RANDOM_STATE],
        'class_weight': [class_weight],
    },
    {
        'random_state': [DEFAULT_RANDOM_STATE],
        'class_weight': [class_weight],
    },
    {
        'gamma': ['auto'],
        'C': [0.5],
        'random_state': [DEFAULT_RANDOM_STATE],
        'class_weight': [class_weight],
    },
    {
        'gamma': ['auto'],
        'random_state': [DEFAULT_RANDOM_STATE],
        'class_weight': [class_weight],
    },
    {
        'random_state': [DEFAULT_RANDOM_STATE],
        'class_weight': [class_weight],
    },
    {
    },
    {
        'n_estimators': [1000],
        'subsample': [.6,.7,.8,1],
        'random_state': [DEFAULT_RANDOM_STATE],
        'class_weight': [class_weight],
    },
    {
        'alpha': [1], 
        'max_iter': [1000],
    },
    {
    }
]

import pdb

logging.info('Início')

# itera a lista de modelos e seus hiperparâmetros
lista_mh = list(zip(model, params))
for m, p in tqdm.tqdm_notebook(lista_mh):
    logging.info('Modelo: {}'.format(m.__name__))
    
    rskfcv = RepeatedStratifiedKFold(n_splits=10, n_repeats=1, random_state=DEFAULT_RANDOM_STATE)
    
    # utiliza o GridSearchCV para encontrar o melhor conjunto de hiperparâmetros 
    # que maximizem o roc_auc score
    cv = GridSearchCV(estimator=m(),param_grid=p, n_jobs=N_JOBS, error_score=0, refit=True, scoring='roc_auc', cv=rskfcv)
    cv.fit(X_train, y_train)
    model = cv.best_estimator_
    best_params = cv.best_params_
    
    # instancia o modelo com os hiperparâmetros escolhidos acima e utiliza validação cruzada 
    # para avaliar todas as métricas escolhidas
    valores = cross_validate(m(**best_params), X_train, y_train, scoring=metrics, cv=rskfcv)
    cv_scores = {k[5:]: np.mean(v) for k, v in valores.items() if k not in ['fit_time', 'score_time']}
    
    # monta um registro com todas as informações coletadas para comparação
    linha = {
        'Modelo': m.__name__,
        'ScoreTreino': cv.score(X_train, y_train),
        'BestParams': best_params,
        'RawScores': {k[5:]: v for k, v in valores.items() if k not in ['fit_time', 'score_time']}
    }
    linha.update(cv_scores)
    results.append(linha)
# Out:
# [2021-10-11 14:10:07,839][<ipython-input-14-15b5d1ba5fd1>:<module>:106 INFO] Início
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=14.0), HTML(value='')))
# [2021-10-11 14:10:07,882][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: RandomForestClassifier
# [2021-10-11 14:10:57,392][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: LogisticRegression
# [2021-10-11 14:10:57,682][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: XGBClassifier
# [2021-10-11 14:13:42,483][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: KNeighborsClassifier
# [2021-10-11 14:13:43,465][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: BaggingClassifier
# [2021-10-11 14:16:16,574][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: ExtraTreesClassifier
# [2021-10-11 14:16:48,354][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: SGDClassifier
# [2021-10-11 14:16:48,812][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: SVC
# [2021-10-11 14:16:59,415][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: NuSVC
# [2021-10-11 14:17:05,685][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: LinearSVC
# [2021-10-11 14:17:06,967][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: BernoulliNB
# [2021-10-11 14:17:07,904][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: LGBMClassifier
# [2021-10-11 14:31:02,653][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: MLPClassifier
# [2021-10-11 14:31:22,887][<ipython-input-14-15b5d1ba5fd1>:<module>:111 INFO] Modelo: AdaBoostClassifier

# %%
# tabela comparativa com os resultados apresentados por cada algoritmo executado
df_results = pd.DataFrame(results)
df_results.sort_values('roc_auc', ascending=False)
# Out:
#                     Modelo  ScoreTreino  \
# 2            XGBClassifier     0.830993
# 0   RandomForestClassifier     0.806853
# 5     ExtraTreesClassifier     0.778812
# 13      AdaBoostClassifier     0.783375
# 1       LogisticRegression     0.739524
# 9                LinearSVC     0.739214
# 6            SGDClassifier     0.733293
# 12           MLPClassifier     0.734710
# 4        BaggingClassifier     0.990785
# 7                      SVC     0.728054
# 3     KNeighborsClassifier     0.807840
# 8                    NuSVC     0.729037
# 10             BernoulliNB     0.700833
# 11          LGBMClassifier     0.991934
#
#                                            BestParams  \
# 2   {'learning_rate': 0.01, 'max_depth': 3, 'min_c...
# 0   {'class_weight': {0: 1, 1: 2.371488033298647},...
# 5   {'class_weight': {0: 1, 1: 2.371488033298647},...
# 13                                                 {}
# 1   {'C': 1, 'class_weight': {0: 1, 1: 2.371488033...
# 9   {'class_weight': {0: 1, 1: 2.371488033298647},...
# 6   {'class_weight': {0: 1, 1: 2.371488033298647},...
# 12                     {'alpha': 1, 'max_iter': 1000}
# 4   {'max_samples': 0.8, 'n_estimators': 1000, 'ra...
# 7   {'C': 0.5, 'class_weight': {0: 1, 1: 2.3714880...
# 3                                 {'n_neighbors': 11}
# 8   {'class_weight': {0: 1, 1: 2.371488033298647},...
# 10                                                 {}
# 11  {'class_weight': {0: 1, 1: 2.371488033298647},...
#
#                                             RawScores   roc_auc  \
# 2   {'roc_auc': [0.7402914839181286, 0.78458516081...  0.765958
# 0   {'roc_auc': [0.7424616228070176, 0.78280336257...  0.765190
# 5   {'roc_auc': [0.7394005847953217, 0.76649305555...  0.753107
# 13  {'roc_auc': [0.7344206871345028, 0.76009685672...  0.751085
# 1   {'roc_auc': [0.7344663742690059, 0.74995431286...  0.738548
# 9   {'roc_auc': [0.7365222953216374, 0.75484283625...  0.737177
# 6   {'roc_auc': [0.7334612573099415, 0.75141630116...  0.735213
# 12  {'roc_auc': [0.7298062865497075, 0.74673336988...  0.734210
# 4   {'roc_auc': [0.6921600877192982, 0.78508771929...  0.727718
# 7   {'roc_auc': [0.7249634502923976, 0.73633954678...  0.726581
# 3   {'roc_auc': [0.704358552631579, 0.739948830409...  0.718508
# 8   {'roc_auc': [0.7175621345029239, 0.73912646198...  0.715788
# 10  {'roc_auc': [0.7117370248538012, 0.69912737573...  0.701566
# 11  {'roc_auc': [0.6349597953216374, 0.76489400584...  0.670534
#
#     balanced_accuracy  average_precision    recall  accuracy  f1_macro  \
# 2            0.701978           0.570179  0.729532  0.690741  0.668653
# 0            0.696533           0.568661  0.752427  0.673765  0.655904
# 5            0.675729           0.548128  0.644126  0.688580  0.656361
# 13           0.625982           0.533068  0.367365  0.731173  0.634903
# 1            0.640081           0.509622  0.482861  0.704012  0.641479
# 9            0.640378           0.515054  0.475558  0.707407  0.642709
# 6            0.629989           0.510925  0.456948  0.700309  0.626468
# 12           0.560498           0.502706  0.181100  0.714815  0.547136
# 4            0.624895           0.510633  0.428812  0.704630  0.629295
# 7            0.614925           0.494911  0.382968  0.709259  0.620914
# 3            0.600123           0.480340  0.334064  0.708333  0.605653
# 8            0.620385           0.493551  0.424592  0.700000  0.624062
# 10           0.580098           0.468461  0.327803  0.682716  0.582750
# 11           0.634523           0.489388  0.498518  0.689815  0.632305
#
#     f1_weighted
# 2      0.703332
# 0      0.687638
# 5      0.698997
# 13     0.711094
# 1      0.702242
# 9      0.704431
# 6      0.691340
# 12     0.659162
# 4      0.697157
# 7      0.695206
# 3      0.687424
# 8      0.692656
# 10     0.665728
# 11     0.691264

# %%
metricas = ['roc_auc', 'average_precision', 'balanced_accuracy', 'f1_weighted' ]

matplotlib.rcParams.update({'font.size': 13})
fig, axis = plt.subplots(2,2, figsize=(14, 10), dpi=80)

axis = np.ravel(axis)
for i, m in enumerate(metricas):
    df_score = pd.DataFrame({m: s for m, s in zip(df_results['Modelo'], df_results['RawScores'].apply(lambda x: x[m]))})
    df_score = pd.melt(df_score, var_name='Modelo', value_name='Score')
    sns.boxplot(x='Modelo', y='Score', data=df_score, color='#45B39D', linewidth=1, ax=axis[i])
    axis[i].set_xlabel('Modelo')
    axis[i].set_ylabel(f'Score ({m})')
    axis[i].set_xticklabels(labels=df_score['Modelo'].drop_duplicates(), rotation=70, ha='right', fontsize=12)
    axis[i].grid(which='major',linestyle='--', linewidth=0.5, )
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Tunning de Hiperparâmetros

# %%
from skopt import forest_minimize


def funcao_otimizacao(params):
    """
    Esta funcao recebe os hiperpâmetros selecionados pela função forest_minimize,
    instancia o RandomForestClassifier com os parâmetros recebidos e avalia o
    modelo com os dados de treino utilizando validação cruzada com 10 folds.
    """
    logging.info(params)
    n_estimators = params[0] 
    max_depth = params[1]
    min_samples_split = params[2]
    min_samples_leaf = params[3]
    max_samples = params[4]
    class_weight = {0: 1, 1: params[5]}
    
    model = RandomForestClassifier(n_estimators=n_estimators, 
                                 max_depth=max_depth,
                                 min_samples_split=min_samples_split,
                                 min_samples_leaf=min_samples_leaf,
                                 max_samples=max_samples,
                                 class_weight=class_weight,
                                 random_state=DEFAULT_RANDOM_STATE, 
                                 n_jobs=-1)
    rskfcv = RepeatedStratifiedKFold(n_splits=10, n_repeats=1, random_state=DEFAULT_RANDOM_STATE)
    score = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=rskfcv)
    return -np.mean(score)

space = [
    (200, 3000), # n_estimators
    (1, 10),     # max_depth
    (2, 20),     # min_samples_split
    (1, 20),     # min_samples_leaf
    (0.4, 1.),   # max_samples
    (2, 10),     # class_weight
]

N_CALLS = 50
pbar = tqdm.tqdm_notebook(total=N_CALLS)
def atualizar_progresso(res):
    pbar.update(1)
    
res = forest_minimize(funcao_otimizacao, space, random_state=DEFAULT_RANDOM_STATE, n_random_starts=10, n_calls=N_CALLS, verbose=1, n_jobs=N_JOBS, callback=atualizar_progresso)
pbar.close()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=50.0), HTML(value='')))
# Iteration No: 1 started. Evaluating function at random point.
# [2021-10-11 14:31:29,792][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [1060, 8, 8, 19, 0.45998494949080176, 9]
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 36.9720
# Function value obtained: -0.7620
# Current minimum: -0.7620
# Iteration No: 2 started. Evaluating function at random point.
# [2021-10-11 14:32:06,767][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [330, 6, 3, 12, 0.9631316254094502, 3]
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 14.8632
# Function value obtained: -0.7663
# Current minimum: -0.7663
# Iteration No: 3 started. Evaluating function at random point.
# [2021-10-11 14:32:21,630][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [1415, 5, 2, 12, 0.7669918962929686, 10]
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 43.9505
# Function value obtained: -0.7646
# Current minimum: -0.7663
# Iteration No: 4 started. Evaluating function at random point.
# [2021-10-11 14:33:05,582][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [674, 10, 17, 15, 0.6736419905302216, 4]
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 23.3450
# Function value obtained: -0.7653
# Current minimum: -0.7663
# Iteration No: 5 started. Evaluating function at random point.
# [2021-10-11 14:33:28,926][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2099, 7, 4, 5, 0.764526911140863, 6]
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 62.7278
# Function value obtained: -0.7631
# Current minimum: -0.7663
# Iteration No: 6 started. Evaluating function at random point.
# [2021-10-11 14:34:31,656][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2414, 2, 5, 14, 0.8850384088698768, 10]
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 72.7106
# Function value obtained: -0.7450
# Current minimum: -0.7663
# Iteration No: 7 started. Evaluating function at random point.
# [2021-10-11 14:35:44,366][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2812, 2, 16, 7, 0.7659979946695726, 9]
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 80.0830
# Function value obtained: -0.7451
# Current minimum: -0.7663
# Iteration No: 8 started. Evaluating function at random point.
# [2021-10-11 14:37:04,450][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [234, 1, 5, 18, 0.7975133706123892, 3]
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 10.5590
# Function value obtained: -0.7290
# Current minimum: -0.7663
# Iteration No: 9 started. Evaluating function at random point.
# [2021-10-11 14:37:15,009][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [1221, 6, 11, 4, 0.5109126733153162, 3]
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 38.1397
# Function value obtained: -0.7671
# Current minimum: -0.7671
# Iteration No: 10 started. Evaluating function at random point.
# [2021-10-11 14:37:53,149][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2977, 2, 11, 4, 0.7587399872866512, 9]
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 87.9322
# Function value obtained: -0.7449
# Current minimum: -0.7671
# Iteration No: 11 started. Searching for the next optimal point.
# [2021-10-11 14:39:21,080][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [389, 5, 15, 18, 0.9916314335040562, 2]
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 18.2323
# Function value obtained: -0.7634
# Current minimum: -0.7671
# Iteration No: 12 started. Searching for the next optimal point.
# [2021-10-11 14:39:39,313][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [210, 5, 3, 20, 0.9391029017552345, 3]
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 9.9443
# Function value obtained: -0.7629
# Current minimum: -0.7671
# Iteration No: 13 started. Searching for the next optimal point.
# [2021-10-11 14:39:49,258][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [320, 4, 5, 12, 0.78185961056411, 2]
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 14.9810
# Function value obtained: -0.7622
# Current minimum: -0.7671
# Iteration No: 14 started. Searching for the next optimal point.
# [2021-10-11 14:40:04,239][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [620, 4, 13, 20, 0.808069996190482, 3]
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 23.7548
# Function value obtained: -0.7602
# Current minimum: -0.7671
# Iteration No: 15 started. Searching for the next optimal point.
# [2021-10-11 14:40:27,994][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [221, 3, 10, 13, 0.9643683747174678, 2]
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 10.3093
# Function value obtained: -0.7559
# Current minimum: -0.7671
# Iteration No: 16 started. Searching for the next optimal point.
# [2021-10-11 14:40:38,304][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [201, 8, 5, 17, 0.59001348071791, 2]
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 9.4670
# Function value obtained: -0.7642
# Current minimum: -0.7671
# Iteration No: 17 started. Searching for the next optimal point.
# [2021-10-11 14:40:47,772][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [363, 3, 6, 18, 0.6976010585703886, 3]
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 16.5838
# Function value obtained: -0.7544
# Current minimum: -0.7671
# Iteration No: 18 started. Searching for the next optimal point.
# [2021-10-11 14:41:04,355][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [1215, 2, 2, 1, 0.4432276196539908, 3]
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 38.0621
# Function value obtained: -0.7463
# Current minimum: -0.7671
# Iteration No: 19 started. Searching for the next optimal point.
# [2021-10-11 14:41:42,418][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2601, 6, 5, 8, 0.8931683047322707, 7]
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 76.3416
# Function value obtained: -0.7655
# Current minimum: -0.7671
# Iteration No: 20 started. Searching for the next optimal point.
# [2021-10-11 14:42:58,760][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [234, 4, 5, 14, 0.830088510153858, 6]
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 11.3716
# Function value obtained: -0.7618
# Current minimum: -0.7671
# Iteration No: 21 started. Searching for the next optimal point.
# [2021-10-11 14:43:10,132][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2957, 6, 13, 1, 0.5497428159780211, 10]
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 84.7714
# Function value obtained: -0.7493
# Current minimum: -0.7671
# Iteration No: 22 started. Searching for the next optimal point.
# [2021-10-11 14:44:34,904][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [237, 3, 6, 17, 0.9032195261542422, 3]
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 10.6220
# Function value obtained: -0.7553
# Current minimum: -0.7671
# Iteration No: 23 started. Searching for the next optimal point.
# [2021-10-11 14:44:45,526][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2958, 6, 2, 5, 0.5019469401405005, 3]
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 84.0382
# Function value obtained: -0.7673
# Current minimum: -0.7673
# Iteration No: 24 started. Searching for the next optimal point.
# [2021-10-11 14:46:09,565][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2741, 5, 7, 3, 0.8322151595903621, 3]
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 77.1149
# Function value obtained: -0.7658
# Current minimum: -0.7673
# Iteration No: 25 started. Searching for the next optimal point.
# [2021-10-11 14:47:26,680][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [212, 6, 5, 18, 0.6523734187149459, 2]
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 9.8425
# Function value obtained: -0.7636
# Current minimum: -0.7673
# Iteration No: 26 started. Searching for the next optimal point.
# [2021-10-11 14:47:36,523][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2667, 6, 12, 7, 0.5852153895980476, 8]
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 81.5639
# Function value obtained: -0.7643
# Current minimum: -0.7673
# Iteration No: 27 started. Searching for the next optimal point.
# [2021-10-11 14:48:58,087][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [269, 4, 5, 19, 0.42718608042137834, 3]
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 12.6649
# Function value obtained: -0.7601
# Current minimum: -0.7673
# Iteration No: 28 started. Searching for the next optimal point.
# [2021-10-11 14:49:10,753][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2373, 1, 18, 17, 0.4176693663836357, 2]
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 69.1037
# Function value obtained: -0.7342
# Current minimum: -0.7673
# Iteration No: 29 started. Searching for the next optimal point.
# [2021-10-11 14:50:19,857][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2822, 5, 16, 3, 0.4501730092420948, 3]
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 82.2591
# Function value obtained: -0.7661
# Current minimum: -0.7673
# Iteration No: 30 started. Searching for the next optimal point.
# [2021-10-11 14:51:42,118][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2437, 5, 14, 16, 0.4070342461212473, 3]
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 71.5225
# Function value obtained: -0.7626
# Current minimum: -0.7673
# Iteration No: 31 started. Searching for the next optimal point.
# [2021-10-11 14:52:53,640][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2777, 6, 19, 16, 0.4130149772541221, 5]
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 89.3686
# Function value obtained: -0.7627
# Current minimum: -0.7673
# Iteration No: 32 started. Searching for the next optimal point.
# [2021-10-11 14:54:23,010][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2630, 4, 17, 2, 0.4371410524242296, 2]
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 75.9207
# Function value obtained: -0.7623
# Current minimum: -0.7673
# Iteration No: 33 started. Searching for the next optimal point.
# [2021-10-11 14:55:38,931][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2334, 5, 11, 5, 0.8369232400797608, 9]
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 68.1193
# Function value obtained: -0.7628
# Current minimum: -0.7673
# Iteration No: 34 started. Searching for the next optimal point.
# [2021-10-11 14:56:47,050][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2212, 4, 20, 18, 0.45166743700625134, 8]
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 65.4877
# Function value obtained: -0.7589
# Current minimum: -0.7673
# Iteration No: 35 started. Searching for the next optimal point.
# [2021-10-11 14:57:52,538][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2839, 6, 18, 18, 0.7962871280955058, 2]
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 82.5957
# Function value obtained: -0.7644
# Current minimum: -0.7673
# Iteration No: 36 started. Searching for the next optimal point.
# [2021-10-11 14:59:15,134][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2599, 6, 19, 9, 0.78007205575105, 10]
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 78.8630
# Function value obtained: -0.7647
# Current minimum: -0.7673
# Iteration No: 37 started. Searching for the next optimal point.
# [2021-10-11 15:00:33,998][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2933, 5, 18, 1, 0.6373947530843006, 10]
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 83.5372
# Function value obtained: -0.7545
# Current minimum: -0.7673
# Iteration No: 38 started. Searching for the next optimal point.
# [2021-10-11 15:01:57,535][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [1096, 6, 18, 2, 0.40173029406137306, 2]
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 37.3612
# Function value obtained: -0.7672
# Current minimum: -0.7673
# Iteration No: 39 started. Searching for the next optimal point.
# [2021-10-11 15:02:34,896][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2173, 5, 11, 17, 0.582327123914013, 2]
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 65.5450
# Function value obtained: -0.7628
# Current minimum: -0.7673
# Iteration No: 40 started. Searching for the next optimal point.
# [2021-10-11 15:03:40,442][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [840, 1, 19, 16, 0.5007517726794561, 4]
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 29.7577
# Function value obtained: -0.7315
# Current minimum: -0.7673
# Iteration No: 41 started. Searching for the next optimal point.
# [2021-10-11 15:04:10,200][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2944, 6, 20, 3, 0.5157196897827236, 7]
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 83.4419
# Function value obtained: -0.7601
# Current minimum: -0.7673
# Iteration No: 42 started. Searching for the next optimal point.
# [2021-10-11 15:05:33,642][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2743, 6, 19, 1, 0.4642885810302988, 2]
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 81.5318
# Function value obtained: -0.7673
# Current minimum: -0.7673
# Iteration No: 43 started. Searching for the next optimal point.
# [2021-10-11 15:06:55,174][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2855, 6, 11, 1, 0.5090556404762675, 4]
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 85.7466
# Function value obtained: -0.7627
# Current minimum: -0.7673
# Iteration No: 44 started. Searching for the next optimal point.
# [2021-10-11 15:08:20,921][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [1284, 6, 10, 1, 0.8340368195353051, 10]
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 41.6972
# Function value obtained: -0.7513
# Current minimum: -0.7673
# Iteration No: 45 started. Searching for the next optimal point.
# [2021-10-11 15:09:02,619][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2791, 6, 15, 7, 0.65568941440483, 10]
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 79.1814
# Function value obtained: -0.7636
# Current minimum: -0.7673
# Iteration No: 46 started. Searching for the next optimal point.
# [2021-10-11 15:10:21,801][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [626, 6, 18, 1, 0.42355243846724644, 5]
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 24.5373
# Function value obtained: -0.7600
# Current minimum: -0.7673
# Iteration No: 47 started. Searching for the next optimal point.
# [2021-10-11 15:10:46,338][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2517, 4, 17, 7, 0.8688114799505787, 9]
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 71.3496
# Function value obtained: -0.7628
# Current minimum: -0.7673
# Iteration No: 48 started. Searching for the next optimal point.
# [2021-10-11 15:11:57,688][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [2916, 6, 2, 4, 0.5085228963346728, 10]
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 83.2424
# Function value obtained: -0.7566
# Current minimum: -0.7673
# Iteration No: 49 started. Searching for the next optimal point.
# [2021-10-11 15:13:20,930][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [246, 4, 19, 12, 0.4997016614629981, 10]
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 11.1333
# Function value obtained: -0.7615
# Current minimum: -0.7673
# Iteration No: 50 started. Searching for the next optimal point.
# [2021-10-11 15:13:32,064][<ipython-input-17-c1a7a1440028>:funcao_otimizacao:10 INFO] [479, 3, 20, 19, 0.6800484137615607, 10]
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 17.8510
# Function value obtained: -0.7531
# Current minimum: -0.7673

# %%
res.x
# Out:
# [2958, 6, 2, 5, 0.5019469401405005, 3]

# %%
X_train.shape
# Out:
# (3240, 20)

# %%
X_test.shape
# Out:
# (811, 20)

# %%
params = [2412, 6, 14, 5, 0.5006957711150638, 2]
params = res.x

n_estimators = params[0] 
max_depth = params[1]
min_samples_split = params[2]
min_samples_leaf = params[3]
max_samples = params[4]
class_weight = {0: 1, 1: params[5]}


model = RandomForestClassifier(n_estimators=n_estimators, 
                             max_depth=max_depth,
                             min_samples_split=min_samples_split,
                             min_samples_leaf=min_samples_leaf,
                             max_samples=max_samples,
                             class_weight=class_weight,
                             random_state=DEFAULT_RANDOM_STATE, 
                             n_jobs=-1)

model.fit(X_train, y_train)

p = model.predict(X_test)

# %%
balanced_accuracy_score(y_test, p)
# Out:
# 0.7009026716168014

# %%
accuracy_score(y_test, p)
# Out:
# 0.6485819975339088

# %%
f1_score(y_test, p)
# Out:
# 0.5839416058394161

# %%
recall_score(y_test, p)
# Out:
# 0.8298755186721992

# %%
precision_score(y_test, p)
# Out:
# 0.45045045045045046

# %%
accuracy_score(y_test, p)
# Out:
# 0.6485819975339088

# %%
roc_auc_score(y_test, model.predict_proba(X_test)[:,1])
# Out:
# 0.7839884982164955

# %%
pd.DataFrame(confusion_matrix(y_test, p), columns=['Predito como Falso','Predito como Verdadeiro'], index=['Falso', 'Verdadeiro'])
# Out:
#             Predito como Falso  Predito como Verdadeiro
# Falso                      326                      244
# Verdadeiro                  41                      200

# %%
print(classification_report(y_test, p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.57      0.70       570
#            1       0.45      0.83      0.58       241
#
#     accuracy                           0.65       811
#    macro avg       0.67      0.70      0.64       811
# weighted avg       0.76      0.65      0.66       811

# %%
matplotlib.rcParams.update({'font.size': 12.5})
plt.figure(figsize=(14, 6), dpi=80)
# plt.title(' Curva Característica de Operação do Receptor (ROC)')
lr_fpr, lr_tpr, thresholds =  roc_curve(y_test.values, model.predict_proba(X_test)[:,1], drop_intermediate=False, pos_label=1)
plt.plot(lr_fpr, lr_tpr, label='RandomForestClassifier',color='#45B39D')
plt.plot([0, 1], [0,1], linestyle='--', label='Aleatório/Chute')
plt.xlabel('Taxa de Falsos Positivos (FPR)')
plt.ylabel('Taxa de Verdadeiros Positivos (TPR ou Recall)')
plt.legend()
plt.grid(which='major',linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
df_histograma = pd.Series(model.predict_proba(X_test)[:,1]).to_frame().rename(columns={0:'Score'})
df_histograma['Bins'] = pd.cut(df_histograma['Score'], bins=np.arange(0,1.05,0.05))
df_histograma['Y'] = y_test.values
df_histograma['Acertos Thr 0.5'] = df_histograma.apply(lambda x: 1 if (1 if x['Score']>=.5 else 0)==x['Y'] else 0,axis=1)

# %%
df_barplot = df_histograma[['Bins','Acertos Thr 0.5']].groupby(['Bins']).apply(lambda x: x['Acertos Thr 0.5'].sum()/x.shape[0]).fillna(0).to_frame().rename(columns={0: 'Acertos (%)'})
df_barplot['Contagem'] = df_histograma[['Bins','Acertos Thr 0.5']].groupby(['Bins']).count()
df_barplot = df_barplot.reset_index()
df_barplot['left'] = df_barplot['Bins'].apply(lambda x: x.left+0.025)

# %%
N = 20
vals = np.ones((N, 4))
vals[:, 0] = np.linspace(.5,45/256, N)
vals[:, 1] = np.linspace(0, 179/256, N)
vals[:, 2] = np.linspace(0, 157/256, N)
newcmp = ListedColormap(vals)

# %%
matplotlib.rcParams.update({'font.size': 12.5})
plt.figure(figsize=(14, 6), dpi=80)
color='#45B39D'
scalarMappable = ScalarMappable(cmap=newcmp)
plt.bar(df_barplot['left'], df_barplot['Contagem'], width=0.05, color=scalarMappable.cmap(df_barplot['Acertos (%)']), alpha=1, linewidth=1, edgecolor='white')
colorbar = plt.colorbar(scalarMappable)
colorbar.set_label('Índice de Acertos na Faixa')
plt.xlim(0,1)
plt.grid(which='both',linestyle='--', linewidth=0.5)
plt.title('Histograma para os Scores dados pelo modelo')
plt.xlabel('Score')
plt.ylabel('Quantidade de Observações')
plt.tight_layout()
plt.xticks(ticks=np.arange(0,1.05, 0.05), rotation=90)
plt.show()
